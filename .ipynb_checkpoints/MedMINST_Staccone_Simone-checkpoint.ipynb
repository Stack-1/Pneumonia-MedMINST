# %% [markdown]
# # ML techniques on MedMNIST-Pneumonia dataset
# #### This is the project for the 2023/2024 ML class in Tor Vergata University
# ##### Author: Staccone Simone 0324525

# %% [markdown]
# ## Introduction
# The aim of this project is to apply different ML techniques to the MedMINST-Pneumonia dataset. The main goal is to use this dataset to train ML models in order to help doctors in their diagnosis, therefore the main focus will be on minimizing the number of instances which are affected by pneumonia, but are missclassified (false negatives).
#
# In particular, this notebook will present three different ML model usefull for binary classification to supply to that task:
# - Logistic Regression
# - Random Forest
# - CNN (Convolutional Neural Network)
#
# The main goal is to optimize the predictions on the linear regression and the CNN model, due the fact that random forest is used to compare the performances obtained in the other two models.

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np

import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import confusion_matrix
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn import metrics

from sklearn import preprocessing

from sklearn.metrics import  accuracy_score, classification_report

from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestClassifier

import keras

from keras.callbacks import EarlyStopping
# Out:
# 2024-01-31 21:25:58.796907: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Data pre-processing
# The first thing to do is to load the data, whihch is present in two files .npy, the first containing the vector representation of the input images (28x28) and the second file containing the label of the images {0,1} -> {Doesn't have pneumonia, Has pneumonia}.
#
# Secondly I want to flatten the image, so that I have a single input vector of length 784 (28*28).
#
# In addtion, I'm rescaling the single pixels to get values normalized between x<sub>max</sub> and x<sub>min</sub>, therefore for each value of the pixel in input I want to have:
# $\hat{x_j} = \frac{x_j - x_{min}}{x_{max} - x_{min}}$
#
# Moreover, having 784 features for each image is computationally expensive, therefore I'm going to reduce the number of features using Best-k (selecting the k pixels which are more meaningfull for the classification). Empirically I choose k=500 to get faster tuning time over regularization term later on, but the final model will be trained and used over all the 784 features.

# %%
# Load the data
X = np.load("pneumonia_images.npy")
y = np.load("pneumonia_labels.npy")

# Rescale to get shape (# of instances, 28*28, 1), normalized between X_max and X_min
scaler = preprocessing.MinMaxScaler()
x_reshaped = X.reshape( (np.shape(X)[0],np.shape(X)[1]*np.shape(X)[2]) )
y_reshaped = y.reshape(np.shape(y)[0])

new_X = scaler.fit_transform( x_reshaped  )

x_dim,y_dim,z_dim = np.shape(X)

if(x_dim == np.size(y)):
    print("Dataset is composed by " + str(x_dim) + " images with dimension: " + str(y_dim) + "x" + str(z_dim))
else:
    raise Exception("[ERROR] Dataset isn't formatted well: different numbers of images and labels")
# Out:
# Dataset is composed by 5232 images with dimension: 28x28

# %% [markdown]
# ## Data Visualization
# Now I want to visualize the data so that I may be able to better understand the domain of the problem or to see realtions bewtween the data I have,
#
# In fact, as a first thing I want to show the relations between a little subset of the features, just to show how some features are more discriminative respect to others (easier to draw decision buondaries) and how a few number of features may be not representative att all, but having 784 maybe could be only computationally heavy with a very few advantages in classification task

# %%
plt.scatter(new_X[:,0],new_X[:,1],c=y)

# %%
plt.scatter(new_X[:,10],new_X[:,11],c=y)

# %%
plt.scatter(new_X[:,100],new_X[:,101],c=y)

# %%
plt.scatter(new_X[:,512],new_X[:,513],c=y)

# %%
plt.scatter(new_X[:,617],new_X[:,618],c=y)

# %% [markdown]
# Now if I consider a plot using three different features and I see how the decision boundary becames more clear

# %%
plt.scatter(new_X[:,728],new_X[:,729],new_X[:,730],c=y)

# %%
# I want also to show what actually the data looks like
for i in range(0,100,10):
    for j in range(1,11):
        plt.subplot(5,10,j)
        frame = plt.imshow(X[i+j], cmap=plt.get_cmap('gray'))
        frame.axes.get_xaxis().set_ticks([]) # Hide x axis
        frame.axes.get_yaxis().set_ticks([]) # Hide y axis
    plt.show()

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

print(np.shape(new_X))
new_X_with_less_features = SelectKBest(chi2, k=500).fit_transform(new_X, y_reshaped)
np.shape(new_X_with_less_features)
# Out:
# (5232, 784)
# (5232, 500)

# %%
print("Here's how actually looks like the nomralized data")
new_X[0][1:10]
# Out:
# Here's how actually looks like the nomralized data
# array([0.45378151, 0.48347107, 0.46638655, 0.4279661 , 0.37974684,
#        0.28571429, 0.19678715, 0.11155378, 0.23529412])

# %%
# We define a debug function to analyze the composition of the dataset
def show_pneumonia_in_dataset(y,label):
    k = 0
    for i in y:
        if i == 1:
            k = k + 1
    print("In the " + str(label) + " dataset we have: " + str(k) + " examples classified has pneumonia")
    print("In the " + str(label) + " dataset we have: " + str(np.size(y) - k) + " examples classified has NOT-pneumonia")

# %% [markdown]
# ### Data Split
# To evaluate my models, I need to split the data between a training set and a testing set. To achieve this result I'm going to use the API train_test_split() in which I can specify how big is the testing set (20% of the entire dataset in this case) and how to initialize the random seed (initialized to 0 in this case; it's important to set alway the same seed, otherwise we would have different sets and therefore different results eaxh time we run this notebook).

# %%
x_train, x_test, y_train, y_test = train_test_split(new_X_with_less_features, y_reshaped, test_size=0.2, random_state=0)

# %%
# Debug function, to check dataset composition
show_pneumonia_in_dataset(y, "whole")
print('')
show_pneumonia_in_dataset(y_train, "train")
print('')
show_pneumonia_in_dataset(y_test, "test")
print('')

print("Features dataset total size is: \t" + str(np.shape(new_X)) )
print("Features training set size is: \t\t" + str(np.shape(x_train)) )
print("Features testing set size is: \t\t" + str(np.shape(x_test)) )

print("Labels dataset total size is: \t\t" + str(np.size(y)) )
print("Labels training set size is: \t\t" + str(np.size(y_train)) )
print("Labels testing set size is: \t\t" + str(np.size(y_test)) )
# Out:
# In the whole dataset we have: 3883 examples classified has pneumonia
# In the whole dataset we have: 1349 examples classified has NOT-pneumonia
#
# In the train dataset we have: 3121 examples classified has pneumonia
# In the train dataset we have: 1064 examples classified has NOT-pneumonia
#
# In the test dataset we have: 762 examples classified has pneumonia
# In the test dataset we have: 285 examples classified has NOT-pneumonia
#
# Features dataset total size is: 	(5232, 784)
# Features training set size is: 		(4185, 500)
# Features testing set size is: 		(1047, 500)
# Labels dataset total size is: 		5232
# Labels training set size is: 		4185
# Labels testing set size is: 		1047

# %% [markdown]
# ## Logistic Regression
# This is the first model I take in consideration, due the fact that I want to do a binary classification. As first try, hust to understand how tthe model works, therefore I use different parameters:
# - C = 1 (default) which is $\frac{1}{\lambda$, so it's the inverse of the regularization term (lower C means higher regularization). It's needed to lower variance (overfitting) of the model.
#
# - solver = 'lbfgs' it's our optimization algorithm, in particular 'lbfgs' is a parallel implementation of SGD (Stochastic Gradient Descent) in whihch the optimizer tune itself the learning rate (using linear search method).
#
# - penalty = 'l2' (default) which is how the regularization term is computed, in this case as $ \lVert w \rVert ^2$ where w are the weights of the model
#
# - class_weight = 'balanced' is used to normalize the weights according to the type of input we have. This is usefull because of class imbalance between labels {0,1} (we have a lot of patient with pneumonia in our dataset)
#
# - random_state = 0 it's the seed to initialize the random values used as weights at the beginning of the optimization
#
# - verbose = 1 to get output in an human-readable format

# %%
# Instance of the model
logisticRegr = LogisticRegression(C = 1,solver = 'lbfgs',penalty="l2", class_weight='balanced', random_state = 0, verbose=1)

# Train the model
logisticRegr.fit(x_train, y_train)

# Test the model
predictions = logisticRegr.predict(x_test)
print('')
show_pneumonia_in_dataset(predictions, "predictions")
print('')
show_pneumonia_in_dataset(y_reshaped, "test")


# Get accuracy
accuracy = logisticRegr.score(x_test, y_test)
print("\nAccuracy is: " + str(accuracy))

# Get all measurement according to permormance metrics
report=classification_report(y_true=y_test, y_pred=predictions,labels=[0,1],target_names=['No','Yes'])
print(report)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          501     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.90082D+03    |proj g|=  2.58981D+02
#
# At iterate   50    f=  4.95239D+02    |proj g|=  4.27758D-01
#  This problem is unconstrained.
# At iterate  100    f=  4.94863D+02    |proj g|=  4.73627D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   501    100    121      1     0     0   4.736D-02   4.949D+02
#   F =   494.86255651486522
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# ...

# %% [markdown]
# We obtain a good result even if we are not using all the features. In particular we have approximately 96% of accuracy, but our goal is to focus over other metrics
#
# I want to minimize the number of predictions where the image has pneumonia but the regression miss classify it (Actual = 1, Predicted = 0), so I want to minimize false negatives and therefore maximize the recall

# %%
show_pneumonia_in_dataset(predictions, "predictions")


# Visualize performance
cm = metrics.confusion_matrix(y_true=y_test, y_pred=predictions)
print('')
print("Total number of test instances: " + str(y_test.size))
print("Total number of predictions: " + str(predictions.size))
print('')
print('Class 1: ')
print('TN FP')
print('FN TP')

plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(accuracy)
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
# In the predictions dataset we have: 734 examples classified has pneumonia
# In the predictions dataset we have: 313 examples classified has NOT-pneumonia
#
# Total number of test instances: 1047
# Total number of predictions: 1047
#
# Class 1:
# TN FP
# FN TP

# %% [markdown]
# ### Try with tuning of C
# First thing I want to do to get better performances is to tune the hyperparameter whihc refers to the regularization term, C. Therefore, I will need to split training set in training and validation set.

# %%
# Use a range to search C
C = np.arange (0.01, 20, 0.01)

print("Input data shape:")
print('x_train: ' + str(np.shape(x_train)))
print('y_train: ' + str(np.shape(y_train)))
print('')

# Split the previous training set in training and validation set
new_X_train, new_X_validation, new_Y_train, new_Y_validation = train_test_split(x_train, y_train, test_size=0.25, random_state=0)

# Print the shapes of the new datasets
print("Data shape after splitting:")
print('new_X_train: ' + str(np.shape(new_X_train)))
print('new_X_validation: ' + str(np.shape(new_X_validation)))
print('new_y_train: ' + str(np.shape(new_Y_train)))
print('new_y_validation' + str(np.shape(new_Y_validation)))
# Out:
# Input data shape:
# x_train: (4185, 500)
# y_train: (4185,)
#
# Data shape after splitting:
# new_X_train: (3138, 500)
# new_X_validation: (1047, 500)
# new_y_train: (3138,)
# new_y_validation(1047,)

# %%
# Actual tuning, for each value of C in the list I train the model on the training set 
# and I evaluate it over the validation set, fixing the value of C thaht maximises the recall
recallList = []
max_recall = [0,0] # [Best racall value, best C value]

for c in C:
    logisticRegrToTune = LogisticRegression(C = c, solver = 'lbfgs',penalty="l2", class_weight='balanced')
    logisticRegrToTune.fit(new_X_train, new_Y_train)
    predictions = logisticRegrToTune.predict(new_X_validation)
    recall = metrics.recall_score(new_Y_validation, predictions,pos_label = 1,average = 'binary')
    if max_recall[0] < recall:
        max_recall = [recall,c]
    recallList.append(recall)

array_di_valori = np.array(recallList)

# Now I print the results to a graph to see the curve of growth of the recall 
# depending on the values of C used
plt.plot(C,recallList)

plt.xlabel('C Value')
plt.ylabel('Recall')
plt.title('Recall according to different C')

plt.show()

# %%
max_recall
# Out:
# [0.9699624530663329, 14.26]

# %%
logisticRegr = LogisticRegression(C = max_recall[1],solver = 'lbfgs',penalty="l2", class_weight='balanced')
logisticRegr.fit(x_train, y_train)
predictions = logisticRegr.predict(x_test)
accuracy = logisticRegr.score(x_test, y_test)
print("Accuracy is: " + str(accuracy))
report=classification_report(y_test,predictions)
print(report)

# Visualiza the data using confusion matrix
cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(accuracy)
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
# Accuracy is: 0.9570200573065902
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       285
#            1       0.98      0.96      0.97       762
#
#     accuracy                           0.96      1047
#    macro avg       0.94      0.96      0.95      1047
# weighted avg       0.96      0.96      0.96      1047

# %% [markdown]
# The model becames slightly better in predicting less false negatives, but it becames  slightly worse in the number of false positives.
#
# Now I want to evaluate my model using all the features that I have. So I get new training and testing sets from scratch.

# %%
x_train, x_test, y_train, y_test = train_test_split(new_X, y_reshaped, test_size=0.2, random_state=0)
np.shape(x_train)
# Out:
# (4185, 784)

# %%
logisticRegr = LogisticRegression(C = max_recall[1],solver = 'lbfgs',penalty="l2", class_weight='balanced')
logisticRegr.fit(x_train, y_train)
predictions = logisticRegr.predict(x_test)
accuracy = logisticRegr.score(x_test, y_test)
print("Accuracy is: " + str(accuracy))
report=classification_report(y_test,predictions)
print(report)
print('')

# Visualiza the data using confusion matrix
cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt="d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(accuracy)
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
# Accuracy is: 0.956064947468959
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       285
#            1       0.98      0.96      0.97       762
#
#     accuracy                           0.96      1047
#    macro avg       0.94      0.95      0.95      1047
# weighted avg       0.96      0.96      0.96      1047

# %% [markdown]
# ### GridSearch
#
# I want to find the best combination of hyperparameters using k-times cross-fold validation. Due to high computational cost, this cell tooks a lot of time to complete (2 h in this version), moreoverthis cell generates a lot of warning "ConvergenceWarning" which are not silenced because I used all the possible cores of my laptop to excecute. Therefore, I will report the image of the final best estimators found by the grid search without excecuting the cell.

# %%
import warnings
warnings.filterwarnings("ignore")
warnings.warn("once")

x_train, x_test, y_train, y_test = train_test_split(new_X, y_reshaped, test_size=0.2, random_state=0)


logModel = LogisticRegression()

param_grid = [    
    {'penalty' : ['l1','l2'],
    'C' : np.arange(7,15,0.1),
     'class_weight' : ['balanced'],
    'solver' : ['lbfgs','saga','newton-cholesky'],
    'max_iter' : [1000]
    }
]

grid_search = GridSearchCV(logModel, param_grid = param_grid, scoring='recall' ,cv = 5, verbose=1, n_jobs=-1)
best_model = grid_search.fit(x_train,y_train)
best_model.best_estimator_

# %% [markdown]
# ![Best Model](assets/Logistic_gridSearch.png)

# %%
# Split again with data containing all the features
x_train, x_test, y_train, y_test = train_test_split(new_X, y_reshaped, test_size=0.2, random_state=0)
np.shape(x_train)
# Out:
# (4185, 784)

# %%
# Use the model with all the features and the new parameters found
logisticRegr = LogisticRegression(C = 13.999999999999975,solver = 'liblinear',penalty="l2", class_weight='balanced',max_iter=1000,n_jobs=-1)
logisticRegr.fit(x_train, y_train)
predictions = logisticRegr.predict(x_test)
accuracy = logisticRegr.score(x_test, y_test)
print("Accuracy is: " + str(accuracy))
report=classification_report(y_test,predictions)
print(report)

cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=",d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(accuracy)
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
# Accuracy is: 0.9608404966571156
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       285
#            1       0.98      0.97      0.97       762
#
#     accuracy                           0.96      1047
#    macro avg       0.95      0.95      0.95      1047
# weighted avg       0.96      0.96      0.96      1047

# %%
# Get missclassified data
index = 0
misclassifiedIndexes = []
for label, predict in zip(y_test, predictions):
    if label != predict: 
        misclassifiedIndexes.append(index)
    index +=1
    
print("Misclassified instances are: " + str( len(misclassifiedIndexes) ))
# Show a subset of missclassified data
plt.figure(figsize=(20,4))
for plotIndex, badIndex in enumerate(misclassifiedIndexes[0:5]):
    plt.subplot(1, 5, plotIndex + 1)
    plt.imshow(np.reshape(x_test[badIndex], (28,28)), cmap=plt.cm.gray)
    plt.title('Predicted: {}, Actual: {}'.format(predictions[badIndex], y_test[badIndex]), fontsize = 15)
# Out:
# Misclassified instances are: 41

# %% [markdown]
# ## Random Forest
# This model is used as a comparison between the other two models we are analyzing. In fact, it requires fewer tuning to obtain better results, thanks to the bagging applyed inside the model.
#
# So, the first thing I want to do is to train the model using a feature selection and than getting the results using all the features. In this case I use a RandomizedSearchCV() as I don't want the best performance possible, but I just want a comparator between the other models.

# %%
x_train, x_test, y_train, y_test = train_test_split(new_X_with_less_features, y_reshaped, test_size=0.2, random_state=0)
np.shape(x_test)
# Out:
# (1047, 500)

# %%
from sklearn.model_selection import RandomizedSearchCV

random_forest = RandomForestClassifier()


param_dist = {'n_estimators': [50,100,500,1000],
              'max_depth': [2,5,7,9,11,13,15],
             'criterion': ['log_loss'],
             'random_state':[0,12312,433,21432]}

rand_search = RandomizedSearchCV(random_forest, 
                                 param_distributions = param_dist, 
                                 n_iter=10,
                                 scoring='recall',
                                 cv=5,
                                 n_jobs=-1)
rand_search.fit(x_train, y_train)

print(rand_search.best_params_)

predictions = rand_search.predict(x_test)
report=classification_report(y_test,predictions)
print(report)
# Out:
# {'random_state': 12312, 'n_estimators': 1000, 'max_depth': 2, 'criterion': 'log_loss'}
#               precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83       285
#            1       0.91      0.98      0.94       762
#
#     accuracy                           0.91      1047
#    macro avg       0.92      0.86      0.88      1047
# weighted avg       0.92      0.91      0.91      1047

# %%
x_train, x_test, y_train, y_test = train_test_split(new_X, y_reshaped, test_size=0.2, random_state=0)
np.shape(x_test)

random_forest = RandomForestClassifier(n_estimators=100,max_depth=2,criterion='log_loss',random_state=0)
random_forest.fit(x_train, y_train)
predictions = random_forest.predict(x_test)
report=classification_report(y_test,predictions)
print(report)

cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=",d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(accuracy)
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81       285
#            1       0.90      0.98      0.94       762
#
#     accuracy                           0.91      1047
#    macro avg       0.91      0.85      0.87      1047
# weighted avg       0.91      0.91      0.90      1047

# %% [markdown]
# ## CNN
# The most interesting model I want to analyze is the Convolutional Neural Network, as it's the most used ML technique for image classification, due the fact that keeps track of the semantic of the position of the pixels in the image.
#
# As first thing I trained a CNN using hyperparameters tuned "by hand", I actually changed a few times the number of layers or units per layer to get the followinf results.
#
# Secondly, I used kersa tuner to fine tune the hyperparameters to get the best performances.
#
# Moreover, I used Dropout and early stopping as regularization techniques.

# %%
import tensorflow as tf
from keras import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D, AveragePooling2D,Dropout, Flatten, Dense

# Model building
model = Sequential()
# Convolutional layer with rectified linear unit activation (32 convolution filters used each of size 3x3)
model.add(Conv2D(128, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(28, 28,1))) 

model.add(Conv2D(128, (3, 3), activation='relu'))

# Choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout for regularization 
model.add(Dropout(0.25))

# Once we extracted the features we want to flatten the output
model.add(Flatten())

# model.add(Dense(128, activation='relu'))


# Fully connected layer
model.add(Dense(1, activation='sigmoid'))



#Adaptive learning rate (adam) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
model.compile(loss=keras.losses.BinaryCrossentropy(),
              optimizer=keras.optimizers.Adam(),
              metrics=[        
                 keras.metrics.BinaryAccuracy(),
                 keras.metrics.FalseNegatives()
              ]
             )
# Out:
# 2024-01-31 21:39:01.851090: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
x_train, x_test, y_train, y_test = train_test_split(new_X, y_reshaped, test_size=0.2, random_state=7564324)
print(np.shape(x_test))

new_X_train, new_X_validation, new_Y_train, new_Y_validation = train_test_split(x_train, y_train, test_size=0.25, random_state=0)
# Out:
# (1047, 784)

# %%
# Reshape all
new_X_train_reshaped = []
new_X_validation_reshaped = []
    
    
for i in new_X_train:
    new_X_train_reshaped.append(i.reshape(28,28,1))
for i in new_X_validation:
    new_X_validation_reshaped.append(i.reshape(28,28,1))
    


# Early stopping
callback = keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
# keras_tuner

batch_size = 16
num_epoch = 128
#model training
model_log = model.fit(np.array(new_X_train_reshaped), new_Y_train,
                      batch_size=batch_size,
                      epochs=num_epoch,
                      verbose=1,
                      validation_data=(np.array(new_X_validation_reshaped), new_Y_validation),
                     callbacks=[callback])
# Out:
# Epoch 1/128
# 197/197 [==============================] - 35s 173ms/step - loss: 0.2559 - binary_accuracy: 0.8891 - false_negatives: 103.0000 - val_loss: 0.1595 - val_binary_accuracy: 0.9351 - val_false_negatives: 9.0000
# Epoch 2/128
# 197/197 [==============================] - 39s 197ms/step - loss: 0.1646 - binary_accuracy: 0.9347 - false_negatives: 100.0000 - val_loss: 0.1314 - val_binary_accuracy: 0.9475 - val_false_negatives: 40.0000
# Epoch 3/128
# 197/197 [==============================] - 38s 191ms/step - loss: 0.1305 - binary_accuracy: 0.9500 - false_negatives: 75.0000 - val_loss: 0.1096 - val_binary_accuracy: 0.9580 - val_false_negatives: 25.0000
# Epoch 4/128
# 197/197 [==============================] - 37s 188ms/step - loss: 0.1320 - binary_accuracy: 0.9525 - false_negatives: 64.0000 - val_loss: 0.1167 - val_binary_accuracy: 0.9589 - val_false_negatives: 32.0000
# Epoch 5/128
# ...

# %%
x_test_reshaped = []
    
    
for i in x_test:
    x_test_reshaped.append(i.reshape(28,28,1))
print(np.shape(x_test_reshaped))
print(np.shape(y_test))
print(x_test_reshaped)

score = model.evaluate(np.array(x_test_reshaped), y_test, verbose=1)
print('Test:', score)
# Out:
# (1047, 28, 28, 1)
# (1047,)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 33/33 [==============================] - 2s 71ms/step - loss: 0.0752 - binary_accuracy: 0.9790 - false_negatives: 10.0000
# Test: [0.07524701952934265, 0.9789875745773315, 10.0]

# %%
fig = plt.figure()
plt.subplot(3,1,1)
plt.plot(model_log.history['loss'])
plt.plot(model_log.history['val_loss'])
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.subplot(3,1,2)

plt.plot(model_log.history['binary_accuracy'])
plt.plot(model_log.history['val_binary_accuracy'])
plt.title('model binary accuracy')
plt.ylabel('binary accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.subplot(3,1,3)
plt.plot(model_log.history['false_negatives'])
plt.plot(model_log.history['val_false_negatives'])
plt.title('model false negatives')
plt.ylabel('false negatives')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predictions = model.predict(np.array(x_test_reshaped) )

k = 0
for i in predictions:
    if i[0] > 0.5:
        k = k+1
        
print(k)
print(np.shape(np.array(x_test_reshaped)))
predictions = np.round(predictions)



cm = metrics.confusion_matrix(y_test, predictions)

plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=",d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score[1])
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
# 33/33 [==============================] - 2s 75ms/step
# 776
# (1047, 28, 28, 1)

# %%
def builder(hp):
    model = Sequential()
    
    model.add(Conv2D(
            filters=128,
            strides=(1, 1),
            kernel_size=(3, 3),
            activation='relu',
            padding='valid',
            input_shape=(28, 28,1))) 
    
    
    for i in range(hp.Int('num_layers',1,5)):
        number_of_units = hp.Int('units', min_value=32, max_value=512, step=32)
        activation_function = hp.Choice("activation", ["relu", "tanh","sigmoid"])
        kernel_size = hp.Choice('kernel_size',[2,3])
        kernel = [ kernel_size, kernel_size ]
        
        model.add( Conv2D(filters=number_of_units,padding='valid', kernel_size=kernel,activation=activation_function) ) 


    # Choose the best features via pooling
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Add dropout for regularization 
    model.add(Dropout(0.25))

    # Once we extracted the features we want to flatten the output
    model.add(Flatten())              
                  
    # Fully connected layer
    model.add(Dense(1, activation='sigmoid') )
 
    model.compile(loss=keras.losses.BinaryCrossentropy(),
              optimizer=keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
              metrics=[        
                 keras.metrics.BinaryAccuracy(),
                 keras.metrics.FalseNegatives()
              ]
             )
    return model

# %%
import keras_tuner as kt
tuner = kt.Hyperband(builder,
                     objective='val_binary_accuracy',
                     max_epochs=128,
                     directory='neural_network_tuning/',
                     project_name='Pneumonia_MedMinst'
                    )

early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

tuner.search(np.array(new_X_train_reshaped), new_Y_train, epochs=128, validation_split=0.2, callbacks=[early_stopping])

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %% [markdown]
# Due to time problems I reported the result of one of the first trials to estimate the best parameters, of course it is not an exaustive analysys beacuse it would require better hardware and time to tune lots of parameters all togheter.
#
# ![KERAS TUNING](assets/keras_tuner.png)

# %%
# Model building
model = Sequential()

# Convolutional layer with rectified linear unit activation (32 convolution filters used each of size 3x3)
model.add(Conv2D(128, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='glorot_normal',
                 input_shape=(28, 28,1))) 

model.add(Conv2D(128, (3, 3), activation='relu',kernel_initializer='glorot_normal'))


model.add(Conv2D(288, (3, 3), activation='relu',kernel_initializer='glorot_normal'))
model.add(Conv2D(288, (3, 3), activation='relu',kernel_initializer='glorot_normal'))
#model.add(Conv2D(288, (3, 3), activation='tanh',padding='valid'))
#model.add(Conv2D(288, (3, 3), activation='tanh',padding='valid'))


# Choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout for regularization 
model.add(Dropout(0.25))
# Once we extracted the features we want to flatten the output
model.add(Flatten())


# Fully connected layer
model.add(Dense(1, activation='sigmoid'))



#Adaptive learning rate (adam) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
model.compile(loss=keras.losses.BinaryCrossentropy(),
              optimizer=keras.optimizers.Adam(),
              metrics=[        
                 keras.metrics.BinaryAccuracy(),
                 keras.metrics.FalseNegatives()
              ]
             )

# %%
# Early stopping
callback = keras.callbacks.EarlyStopping(monitor='val_loss',patience = 10)
# keras_tuner

batch_size = 16
num_epoch = 128
#model training
model_log = model.fit(np.array(new_X_train_reshaped), new_Y_train,
                      batch_size=batch_size,
                      epochs=num_epoch,
                      verbose=1,
                      validation_data=(np.array(new_X_validation_reshaped), new_Y_validation),
                     callbacks=[callback])
# Out:
# Epoch 1/128
# 197/197 [==============================] - 135s 677ms/step - loss: 0.3041 - binary_accuracy: 0.8697 - false_negatives_2: 88.0000 - val_loss: 0.2395 - val_binary_accuracy: 0.9064 - val_false_negatives_2: 79.0000
# Epoch 2/128
# 197/197 [==============================] - 116s 590ms/step - loss: 0.1793 - binary_accuracy: 0.9280 - false_negatives_2: 105.0000 - val_loss: 0.1747 - val_binary_accuracy: 0.9341 - val_false_negatives_2: 57.0000
# Epoch 3/128
# 197/197 [==============================] - 120s 611ms/step - loss: 0.1788 - binary_accuracy: 0.9273 - false_negatives_2: 106.0000 - val_loss: 0.1442 - val_binary_accuracy: 0.9427 - val_false_negatives_2: 11.0000
# Epoch 4/128
# 197/197 [==============================] - 132s 671ms/step - loss: 0.1360 - binary_accuracy: 0.9471 - false_negatives_2: 74.0000 - val_loss: 0.1154 - val_binary_accuracy: 0.9618 - val_false_negatives_2: 21.0000
# Epoch 5/128
# ...

# %%
x_test_reshaped = []
    
    
for i in x_test:
    x_test_reshaped.append(i.reshape(28,28,1))
print(np.shape(x_test_reshaped))
print(np.shape(y_test))
print(x_test_reshaped)

score = model.evaluate(np.array(x_test_reshaped), y_test, verbose=1)
print('Test:', score)
# Out:
# (1047, 28, 28, 1)
# (1047,)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 33/33 [==============================] - 8s 256ms/step - loss: 0.1217 - binary_accuracy: 0.9771 - false_negatives_2: 17.0000
# Test: [0.1217135414481163, 0.9770773649215698, 17.0]

# %%
fig = plt.figure()
plt.subplot(3,1,1)
plt.plot(model_log.history['loss'])
plt.plot(model_log.history['val_loss'])
plt.title('model validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.subplot(3,1,2)

plt.plot(model_log.history['binary_accuracy'])
plt.plot(model_log.history['val_binary_accuracy'])
plt.title('model binary accuracy')
plt.ylabel('binary accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.subplot(3,1,3)
plt.plot(model_log.history['false_negatives_2'])
plt.plot(model_log.history['val_false_negatives_2'])
plt.title('model false negatives')
plt.ylabel('false negatives')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
predictions = model.predict(np.array(x_test_reshaped) )

k = 0
for i in predictions:
    if i[0] > 0.5:
        k = k+1
        
print(k)
print(np.shape(np.array(x_test_reshaped)))
predictions = np.round(predictions)



cm = metrics.confusion_matrix(y_test, predictions)

plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=",d", linewidths=.5, square = True, cmap = 'Blues');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score[1])
plt.title(all_sample_title, size = 15);
plt.show()
# Out:
# 33/33 [==============================] - 8s 249ms/step
# 764
# (1047, 28, 28, 1)

# %% [markdown]
# Adding a layer did not made the model better on predictions, in particular it worsen a lot the prediction over false positives instances, which is against our purpose. Therefore; it should be reconsiderened this optimization obtained adding a convolutional layer and using Golorot kerner initialization over uniform random.
#
# So I would consider the first model obtained (or tune better the second one), even if the last CNN obtain is still better than both logistic regression and random forest.

# %% [markdown]
# ## Conclusions
# In conclusion I got good results considering this notebook as an excercise of optimization, but to get the best possible results there are a few things that I could have added_
# - A proper tuning for all three the models considering all the most important parameters for each model, specificcally for our binary classification task
# - Adding feature mapping for the linear regression, in fact this was the worst model of all. This may be caused by lack of complexity for the funxtion we are estimating (We used linear even if we had a lot of features and decision buondaries between data should have been more complex).
# - Tune the logistic regression hyperparameter of the feature mapping complexity (M=? --> which degree has the polynomial function in which we are mapping the features?, 2/3/4 ecc...)
# - Adding to the CNN more layers and also dense layers in the middle, in fact this model may be way more complex and may depend less on drpout (having less layers dropout has a more important impact on the training)
# - Tune the CNN also looking at the batch size used to train the model
# - Adding some form of normalization between the layers of the CNN (E.g. BatchNormalization)
# - Considering some sort of dataset augmentation obtained rotating the images
# - Experimenting more over the weigths initialization in the CNN to see if we could reach global minima of the function, or at least a better minima
#
# So, taking in consideration that our goal was to minimize the false negatives, not having a dummy classifier, so maintaing an high accuracy, the best model obtained is the CNN, even if we get quite good results even using a simple Random Forest which takes way less effort and way less time to be trained and used.
#
# Thank you for your time :)\
# Staccone Simone 0324525
